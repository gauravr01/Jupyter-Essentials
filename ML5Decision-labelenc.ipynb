# %%
import pandas as pd
import numpy as np

# create sample data
data = {'company': ['Google', 'Meta', 'Apple', 'Google', 'Meta', 'Apple', 'Google'],
        'job': ['Software Engineer', 'Data Analyst', 'Product Manager', 'Sales Manager','Software Engineer', 'Data Analyst', 'Product Manager'],
        'degree': ['Masters', 'Bachelors', 'Masters', 'Masters', 'Bachelors', 'Masters', 'Masters'],
        'salary_more_then_100k': [1, 1, 0, 1,1, 0, 1]}

# create pandas dataframe
df = pd.DataFrame(data)

# print dataframe

df
# Out:
#   company                job     degree  salary_more_then_100k
# 0  Google  Software Engineer    Masters                      1
# 1    Meta       Data Analyst  Bachelors                      1
# 2   Apple    Product Manager    Masters                      0
# 3  Google      Sales Manager    Masters                      1
# 4    Meta  Software Engineer  Bachelors                      1
# 5   Apple       Data Analyst    Masters                      0
# 6  Google    Product Manager    Masters                      1

# %%
inputs = df.drop('salary_more_then_100k',axis='columns')
target = df['salary_more_then_100k']
inputs
# Out:
#   company                job     degree
# 0  Google  Software Engineer    Masters
# 1    Meta       Data Analyst  Bachelors
# 2   Apple    Product Manager    Masters
# 3  Google      Sales Manager    Masters
# 4    Meta  Software Engineer  Bachelors
# 5   Apple       Data Analyst    Masters
# 6  Google    Product Manager    Masters

# %%
target
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    1
# 5    0
# 6    1
# Name: salary_more_then_100k, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le_company = LabelEncoder()
le_job = LabelEncoder()
le_degree = LabelEncoder()

# %%
inputs['company_n'] = le_company.fit_transform(inputs['company'])
inputs['job_n'] = le_job.fit_transform(inputs['job'])
inputs['degree_n'] = le_degree.fit_transform(inputs['degree'])

# %%
inputs
# Out:
#   company                job     degree  company_n  job_n  degree_n
# 0  Google  Software Engineer    Masters          1      3         1
# 1    Meta       Data Analyst  Bachelors          2      0         0
# 2   Apple    Product Manager    Masters          0      1         1
# 3  Google      Sales Manager    Masters          1      2         1
# 4    Meta  Software Engineer  Bachelors          2      3         0
# 5   Apple       Data Analyst    Masters          0      0         1
# 6  Google    Product Manager    Masters          1      1         1

# %%
inputs_n = inputs.drop(['company','job','degree'],axis='columns')
inputs_n
# Out:
#    company_n  job_n  degree_n
# 0          1      3         1
# 1          2      0         0
# 2          0      1         1
# 3          1      2         1
# 4          2      3         0
# 5          0      0         1
# 6          1      1         1

# %%
target
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    1
# 5    0
# 6    1
# Name: salary_more_then_100k, dtype: int64

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

# %%
model.fit(inputs_n, target)
# Out:
# DecisionTreeClassifier()

# %%
model.predict([[2,1,0]])
# Out:
# D:\AnaCONDA1\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
#Exercise
import pandas as pd
df = pd.read_csv("Titanic1.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
inputs = df.drop('Survived',axis='columns')
target = df['Survived']
inputs
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le_pc = LabelEncoder()
le_sx = LabelEncoder()
le_age = LabelEncoder()
le_fare = LabelEncoder()

# %%
inputs['pc_n'] = le_company.fit_transform(inputs['Pclass'])
inputs['sx_n'] = le_job.fit_transform(inputs['Sex'])
inputs['age_n'] = le_degree.fit_transform(inputs['Age'])

inputs['fare_n'] = le_degree.fit_transform(inputs['Fare'])

# %%
inputs
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
inputs_n = inputs.drop(['Pclass','Sex','Age','Fare','PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis='columns')
inputs_n
# Out:
#      pc_n  sx_n  age_n  fare_n
# 0       2     1     28      18
# 1       0     0     51     207
# 2       2     0     34      41
# 3       0     0     47     189
# 4       2     1     47      43
# ..    ...   ...    ...     ...
# 886     1     1     35      85
# 887     0     0     24     153
# 888     2     0     88     131
# 889     0     1     34     153
# 890     2     1     42      30
#
# [891 rows x 4 columns]

# %%
inputs_n.median()
# Out:
# pc_n       2.0
# sx_n       1.0
# age_n     42.0
# fare_n    94.0
# dtype: float64

# %%
# import pandas as pd

# df = pd.read_csv('your_data_file.csv')

# median_age = df['age_n'].median()

# print("Median age is:", median_age)
# df.fillna(df.median(), inplace=True)

# %%
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

# %%
model.fit(inputs_n, target)
# Out:
# DecisionTreeClassifier()

# %%
model.predict([[2,0,30,20]])
# Out:
# D:\AnaCONDA1\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
model.score(inputs_n, target)
# Out:
# 0.9797979797979798
